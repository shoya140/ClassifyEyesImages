# %%
from pandas import read_csv
import numpy
import matplotlib.image as mpimg

# %%
timestamp_data = read_csv('./data/Timestamp.csv',names=['time','position'],skiprows=1)

# %%
i = 0
for picture_position in timestamp_data['position']:
    i = i +1
    if picture_position == 3:
        
        subplot(121)
        left_eye_filepath = ('./data/'+str('%.5f' %timestamp_data['time'][i])+'_left.jpg')
        left_eye_image = mpimg.imread(left_eye_filepath)
        plt.imshow(left_eye_image)
        
        subplot(122)
        right_eye_filepath = ('./data/'+str('%.5f' %timestamp_data['time'][i])+'_right.jpg')
        right_eye_image = mpimg.imread(right_eye_filepath)
        plt.imshow(right_eye_image)
        
        figure()
